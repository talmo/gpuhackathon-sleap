# %% [markdown]
# # Download data
#
# This notebook downloads trained SLEAP models and extracts them, as well as real data and labels.

# %%
# Test video:
# !wget -P data https://storage.googleapis.com/sleap-data/reference/flies13/190719_090330_wt_18159206_rig1.2%4015000-17560.mp4

# Test video labels (from predictions/not necessary for inference benchmarking):
# !wget -P data https://storage.googleapis.com/sleap-data/reference/flies13/190719_090330_wt_18159206_rig1.2%4015000-17560.slp

# Bottom-up model:
# !wget -P data https://storage.googleapis.com/sleap-data/reference/flies13/bu.210506_230852.multi_instance.n%3D1800.zip

# Top-down model (two-stage):
# !wget -P data https://storage.googleapis.com/sleap-data/reference/flies13/centroid.fast.210504_182918.centroid.n%3D1800.zip
# !wget -P data https://storage.googleapis.com/sleap-data/reference/flies13/td_fast.210505_012601.centered_instance.n%3D1800.zip
# Out:
# --2021-05-23 01:02:06--  https://storage.googleapis.com/sleap-data/reference/flies13/190719_090330_wt_18159206_rig1.2%4015000-17560.mp4
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.10.240, 142.250.80.16, 172.217.12.208, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.10.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85343812 (81M) [video/mp4]
# Saving to: ‘data/190719_090330_wt_18159206_rig1.2@15000-17560.mp4’
#
# 190719_090330_wt_18 100%[===================>]  81.39M  65.5MB/s    in 1.2s
#
# 2021-05-23 01:02:07 (65.5 MB/s) - ‘data/190719_090330_wt_18159206_rig1.2@15000-17560.mp4’ saved [85343812/85343812]
#
# --2021-05-23 01:02:07--  https://storage.googleapis.com/sleap-data/reference/flies13/190719_090330_wt_18159206_rig1.2%4015000-17560.slp
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.10.240, 2607:f8b0:4006:819::2010, 2607:f8b0:4006:812::2010, ...
# ...

# %%
# !apt update && apt install unzip
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic InRelease [242 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1412 kB]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2152 kB]33m
# Get:7 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [423 kB]
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# ...

# %%
# !unzip "data/bu.210506_230852.multi_instance.n=1800.zip" -d "data/bu_sleap_model"
# !unzip "data/centroid.fast.210504_182918.centroid.n=1800.zip" -d "data/centroid_sleap_model"
# !unzip "data/td_fast.210505_012601.centered_instance.n=1800.zip" -d "data/td_sleap_model"
# Out:
# Archive:  data/bu.210506_230852.multi_instance.n=1800.zip
#   inflating: data/bu_sleap_model/best_model.h5
#   inflating: data/bu_sleap_model/initial_config.json
#   inflating: data/bu_sleap_model/labels_gt.test.slp
#   inflating: data/bu_sleap_model/labels_gt.train.slp
#   inflating: data/bu_sleap_model/labels_gt.val.slp
#   inflating: data/bu_sleap_model/labels_pr.test.slp
#   inflating: data/bu_sleap_model/labels_pr.train.slp
#   inflating: data/bu_sleap_model/labels_pr.val.slp
#  extracting: data/bu_sleap_model/metrics.test.npz
#  extracting: data/bu_sleap_model/metrics.train.npz
#  extracting: data/bu_sleap_model/metrics.val.npz
#   inflating: data/bu_sleap_model/model_info.json
#   inflating: data/bu_sleap_model/training_config.json
#   inflating: data/bu_sleap_model/training_log.csv
# Archive:  data/centroid.fast.210504_182918.centroid.n=1800.zip
#   inflating: data/centroid_sleap_model/best_model.h5
#   inflating: data/centroid_sleap_model/initial_config.json
# ...
